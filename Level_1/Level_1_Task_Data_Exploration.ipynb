# %% [markdown]
# # Level 1 - Task 1: Data Exploration and Preprocessing
#
# ## Objective
# The objective of this task is to explore the restaurant dataset, understand its structure, identify missing values, check data types, and analyze the distribution of the target variable (Aggregate Rating).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd

df = pd.read_csv("../Dataset/Dataset.csv")

df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Dataset Shape

# %%
# Display the number of rows and columns
print("Shape of Dataset:", df.shape)
# Out:
# Shape of Dataset: (9551, 21)

# %% [markdown]
# ## Dataset Information

# %%
# Display dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   str
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   str
#  4   Address               9551 non-null   str
#  5   Locality              9551 non-null   str
#  6   Locality Verbose      9551 non-null   str
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   str
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   str
#  12  Has Table booking     9551 non-null   str
#  13  Has Online delivery   9551 non-null   str
#  14  Is delivering now     9551 non-null   str
# ...

# %% [markdown]
# ## Data Types

# %%
# Data types
print(df.dtypes)
# Out:
# Restaurant ID             int64
# Restaurant Name             str
# Country Code              int64
# City                        str
# Address                     str
# Locality                    str
# Locality Verbose            str
# Longitude               float64
# Latitude                float64
# Cuisines                    str
# Average Cost for two      int64
# Currency                    str
# Has Table booking           str
# Has Online delivery         str
# Is delivering now           str
# Switch to order menu        str
# Price range               int64
# Aggregate rating        float64
# Rating color                str
# Rating text                 str
# Votes                     int64
# dtype: object

# %% [markdown]
# ## Missing Values

# %%
# Missing values
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ## Checking Missing Values
#
# The dataset was checked for missing values in all columns using the `isnull().sum()` function.
# This helps identify columns that contain null values and need preprocessing before analysis.

# %%
# Check missing values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ### Observation
#
# - Most columns do not contain any missing values.
# - Only the **Cuisines** column contains **9 missing values**.
# - Since only 9 out of 9551 records have missing values, these rows can be safely removed without significantly affecting the dataset.

# %% [markdown]
# ## Handling Missing Values
#
# Since only the **Cuisines** column contained **9 missing values**, these records were removed using the `dropna()` function. The dataset was then checked again to ensure that no missing values remained.

# %%
df = df.dropna()

print("Dataset Shape:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (9542, 21)
#
# Missing Values:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ## Observation
#
# - The dataset contained **9 missing values**, all in the **Cuisines** column.
# - Since these missing records represented less than **0.1%** of the dataset (9 out of 9551 rows), they were removed using the `dropna()` function.
# - After preprocessing, the dataset contains **9542 rows**, **21 columns**, and **no missing values**.

# %% [markdown]
# ## Distribution of Aggregate Rating

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["Aggregate rating"], bins=10)

plt.title("Distribution of Aggregate Rating")
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")

plt.show()

# %% [markdown]
# ## Observation
#
# - Most restaurants have ratings between 3.0 and 4.0.
# - A large number of restaurants have a rating of 0, indicating unrated restaurants.
# - The distribution is not perfectly balanced, showing a slight class imbalance.

# %% [markdown]
# ## Observation
#
# - The dataset originally contained 9551 rows and 21 columns.
# - There were 9 missing values in the "Cuisines" column.
# - Missing values were handled by removing those rows using `dropna()`.
# - After preprocessing, the dataset contains 9542 rows and 21 columns.
# - No missing values remain in the dataset.

# %% [markdown]
# # Level 1 - Task 2: Descriptive Analysis
#
# ## Objective
#
# The objective of this task is to perform descriptive analysis on the restaurant dataset by calculating statistical measures for numerical columns and analyzing the distribution of categorical variables such as Country Code, City, and Cuisines.v

# %% [markdown]
# ## Statistical Measures for Numerical Columns

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## Observation
#
# - The dataset contains **9,542 restaurant records** after preprocessing.
# - The average **Aggregate Rating** is **2.67**, while the median is **3.20**, indicating that many restaurants have ratings around 3.
# - The **Average Cost for Two** varies widely, with a mean of **1200.33** and a maximum value of **800000**, showing the presence of significant outliers.
# - The **Price Range** mostly lies between **1 and 2**, suggesting that most restaurants are affordable.
# - The **Votes** column also contains large variations, indicating that some restaurants are much more popular than others.

# %% [markdown]
# # Distribution of Country Code

# %%
# Distribution of Country Code

df["Country Code"].value_counts()
# Out:
# Country Code
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
#
# - Country Code **1** has the highest number of restaurants (**8652**), making it the dominant country in the dataset.
# - Country Code **216** is the second most common with **425** restaurants.
# - All other country codes have significantly fewer restaurants.
# - The dataset is highly imbalanced, with the majority of restaurants belonging to a single country.

# %% [markdown]
# ## Distribution of City
#
# This section analyzes the distribution of restaurants across different cities by counting the number of restaurants in each city.

# %%
# Distribution of City
df["City"].value_counts()
# Out:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
#              ...
# Yorkton         1
# Mohali          1
# Panchkula       1
# Bandung         1
# Randburg        1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# ## Observation
#
# - Country Code **1** has the highest number of restaurants (**8652**), making it the dominant country in the dataset.
# - Country Code **216** is the second most common with **425** restaurants.
# - The remaining country codes contain significantly fewer restaurants.
# - The distribution is highly imbalanced, with most restaurants belonging to a single country.

# %% [markdown]
# # Distribution of City
#
# This section analyzes the distribution of restaurants across different cities by counting the number of restaurants in each city.

# %%
df["City"].value_counts()
# Out:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
#              ...
# Yorkton         1
# Mohali          1
# Panchkula       1
# Bandung         1
# Randburg        1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# ## Observation
#
# - Restaurants are distributed across multiple cities.
# - Some cities contain a significantly higher number of restaurants than others.
# - The distribution is uneven, indicating that restaurant businesses are concentrated in a few major cities.
# - The city with the highest count has the largest restaurant presence in the dataset.

# %% [markdown]
# # Top 10 Cities with Highest Number of Restaurants
#
# This section identifies the top 10 cities that have the highest number of restaurants in the dataset.

# %%
df["City"].value_counts().head(10)
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Amritsar          21
# Bhubaneshwar      21
# Guwahati          21
# Lucknow           21
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
#
# - **New Delhi** has the highest number of restaurants in the dataset with **5,473** restaurants.
# - **Gurgaon** and **Noida** are the second and third most represented cities, with **1,118** and **1,080** restaurants, respectively.
# - **Faridabad** has a considerably lower count (**251**) compared to the top three cities.
# - The remaining cities in the top 10, such as **Ghaziabad**, **Ahmedabad**, **Amritsar**, **Bhubaneshwar**, **Guwahati**, and **Lucknow**, each have relatively few restaurants.
# - The restaurant distribution is highly concentrated in **New Delhi**, indicating that it is the primary city represented in the dataset.

# %% [markdown]
# # Distribution of Cuisines
#
# This section explores the frequency of different cuisines offered by restaurants in the dataset.

# %%
df["Cuisines"].value_counts()
# Out:
# Cuisines
# North Indian                          936
# North Indian, Chinese                 511
# Chinese                               354
# Fast Food                             354
# North Indian, Mughlai                 334
#                                      ...
# Restaurant Cafe, Turkish, Desserts      1
# Desserts, B�_rek                        1
# Burger, Izgara                          1
# World Cuisine, Patisserie, Cafe         1
# Italian, World Cuisine                  1
# Name: count, Length: 1825, dtype: int64

# %% [markdown]
# ## Observation
#
# - The dataset contains a wide variety of cuisines.
# - Some cuisines are offered by many restaurants, while others appear only a few times.
# - The distribution indicates that customer preferences are concentrated around a few popular cuisines.

# %% [markdown]
# # Top 10 Most Common Cuisines
#
# This section identifies the ten most frequently occurring cuisines in the dataset.

# %%
df["Cuisines"].value_counts().head(10)
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
#
# - **North Indian** cuisine is the most common cuisine in the dataset, appearing in **936** restaurants.
# - **North Indian, Chinese** is the second most popular cuisine combination with **511** restaurants.
# - **Chinese** and **Fast Food** cuisines are equally popular, each appearing in **354** restaurants.
# - Cuisine combinations such as **North Indian, Mughlai** and **North Indian, Mughlai, Chinese** also appear frequently, indicating that restaurants often serve multiple cuisines.
# - The results show that **North Indian cuisine dominates the dataset**, while a variety of other cuisines contribute to the overall diversity of restaurant offerings.

# %% [markdown]
# ### Key Findings
#
# - Basic statistical measures were calculated for all numerical columns using descriptive statistics.
# - Most restaurants have aggregate ratings between **3.0 and 4.5**, while a few restaurants have a rating of **0**, indicating unrated restaurants.
# - The **Votes** column shows high variability, suggesting that restaurant popularity differs significantly.
# - The majority of restaurants belong to **Country Code 1**, indicating that one country dominates the dataset.
# - **New Delhi** has the highest number of restaurants, followed by **Gurgaon** and **Noida**.
# - **North Indian** cuisine is the most common cuisine, followed by combinations such as **North Indian, Chinese** and **Chinese**.
#
# ### Conclusion
#
# The descriptive analysis provides valuable insights into the numerical and categorical features of the dataset. It highlights the dominant countries, cities, and cuisines while summarizing the statistical characteristics of the numerical variables. These findings help in understanding the overall structure and distribution of the restaurant dataset.

# %% [markdown]
# # Level 1 - Task 3: Geospatial Analysis

# %% [markdown]
# ## Objective
#
# The objective of this task is to analyze the geographical distribution of restaurants using their latitude and longitude coordinates. It also examines how restaurants are distributed across different cities and countries and explores whether there is any relationship between a restaurant's location and its aggregate rating.

# %% [markdown]
# ## Restaurant Locations on the Map
#
# This section visualizes the geographical locations of restaurants using their latitude and longitude coordinates.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.scatter(
    df["Longitude"],
    df["Latitude"],
    alpha=0.5
)

plt.title("Restaurant Locations")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.show()

# %% [markdown]
# ## Observation
#
# - The scatter plot shows the geographical distribution of restaurants based on their latitude and longitude coordinates.
# - Restaurants are spread across multiple regions, indicating that the dataset includes restaurants from different countries and cities.
# - Several dense clusters of points are visible, suggesting that a large number of restaurants are concentrated in specific geographic locations.
# - Some locations contain only a few restaurants, resulting in isolated data points on the map.
# - Overall, the dataset has a wide geographical coverage, with restaurants distributed across different parts of the world.

# %% [markdown]
# ## Distribution of Restaurants Across Cities
#
# This section analyzes how restaurants are distributed across different cities.

# %%
df["City"].value_counts().head(10)
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Amritsar          21
# Bhubaneshwar      21
# Guwahati          21
# Lucknow           21
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
#
# - Restaurants are not evenly distributed across cities.
# - New Delhi has the highest number of restaurants (5,473), making it the dominant city in the dataset.
# - Gurgaon (1,118) and Noida (1,080) also have a large number of restaurants compared to other cities.
# - The remaining cities have significantly fewer restaurants, indicating an uneven distribution.
# - This suggests that the dataset is primarily focused on restaurants located in major Indian cities.

# %% [markdown]
# ## Distribution of Restaurants Across Countries
#
# This section analyzes the distribution of restaurants across different countries using the Country Code.

# %%
df["Country Code"].value_counts()
# Out:
# Country Code
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %% [markdown]
# ## Observation
#
# - The majority of restaurants belong to Country Code 1, with 8,652 restaurants.
# - All other country codes have considerably fewer restaurants.
# - This indicates that the dataset is heavily concentrated in one country, while the remaining countries contribute only a small portion of the data.
# - The distribution of restaurants across countries is highly imbalanced.

# %% [markdown]
# ## Correlation Between Restaurant Location and Aggregate Rating
#
# This section examines whether there is any relationship between the geographical location of restaurants and their aggregate ratings.

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    df["Longitude"],
    df["Aggregate rating"],
    alpha=0.5
)

plt.title("Longitude vs Aggregate Rating")
plt.xlabel("Longitude")
plt.ylabel("Aggregate Rating")

plt.show()

# %% [markdown]
# ## Observation
#
# - The scatter plot does not show any strong relationship between **longitude** and **aggregate rating**.
# - Restaurants with both high and low ratings are distributed across different longitude values.
# - Most restaurants have aggregate ratings between **3.0 and 4.5**, regardless of their longitude.
# - A few restaurants have an aggregate rating of **0**, representing unrated restaurants, which are also spread across different locations.
# - Overall, longitude does not appear to have a significant influence on restaurant ratings.

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    df["Latitude"],
    df["Aggregate rating"],
    alpha=0.5
)

plt.title("Latitude vs Aggregate Rating")
plt.xlabel("Latitude")
plt.ylabel("Aggregate Rating")

plt.show()

# %% [markdown]
# ## Observation
#
# - The scatter plot shows no clear relationship between **latitude** and **aggregate rating**.
# - Restaurants across different latitude values have a wide range of ratings.
# - Most restaurants have ratings between **3.0 and 4.5**, irrespective of their latitude.
# - A small number of restaurants have an aggregate rating of **0**, indicating unrated restaurants.
# - Overall, latitude does not appear to significantly affect restaurant ratings.

# %% [markdown]
# # Overall Observation
#
# - Both the **Latitude vs Aggregate Rating** and **Longitude vs Aggregate Rating** scatter plots show no strong correlation between restaurant location and aggregate rating.
# - Restaurants with similar ratings are distributed across various geographical locations.
# - Most restaurants have ratings between **3.0 and 4.5**, regardless of their latitude or longitude.
# - Therefore, geographical location alone does not appear to have a significant impact on restaurant ratings in this dataset.

# %% [markdown]
# # Final Observation
#
# - The geospatial analysis shows that restaurants are widely distributed across multiple cities and countries, indicating broad geographical coverage.
# - A significant concentration of restaurants is found in **New Delhi**, followed by **Gurgaon** and **Noida**, making these the major restaurant hubs in the dataset.
# - The majority of restaurants belong to **Country Code 1**, while the remaining countries contribute a relatively smaller number of restaurants.
# - Scatter plots of **Latitude vs Aggregate Rating** and **Longitude vs Aggregate Rating** show no clear relationship between restaurant location and customer ratings.
# - Most restaurants have aggregate ratings between **3.0 and 4.5**, regardless of their geographical coordinates.
# - Overall, geographical location does not appear to have a significant impact on restaurant ratings, although the dataset is heavily concentrated in a few major cities and one dominant country.

# %% [markdown]
# # Final Summary
#
# In this level, the restaurant dataset was explored and analyzed through data preprocessing, descriptive analysis, and geospatial analysis.
#
# ### Key Findings
#
# - The dataset originally contained **9,551 rows and 21 columns**.
# - Only **9 missing values** were found in the **Cuisines** column, and they were removed since they represented a very small portion of the dataset.
# - Numerical analysis showed that most restaurants have aggregate ratings between **3.0 and 4.5**, while a few restaurants have a rating of **0**, indicating unrated restaurants.
# - The majority of restaurants belong to **Country Code 1**.
# - **New Delhi** has the highest number of restaurants, followed by **Gurgaon** and **Noida**.
# - **North Indian** cuisine is the most common cuisine in the dataset.
# - Geospatial analysis showed that restaurants are distributed across multiple cities and countries.
# - Scatter plots comparing **latitude** and **longitude** with **aggregate rating** indicate **no significant correlation** between restaurant location and customer ratings.
#
# ### Conclusion
#
# The dataset was successfully cleaned, explored, and analyzed. The analysis provided valuable insights into restaurant distribution, cuisines, ratings, and geographical coverage, creating a strong foundation for further analysis in the next level.

# %% [markdown]
# # Level 2 - Task 1: Table Booking and Online Delivery
#
# ## Objective
#
# The objective of this task is to analyze the availability of table booking and online delivery services offered by restaurants. It also compares the average aggregate ratings of restaurants based on these services to understand their impact on customer ratings.

# %% [markdown]
# # Percentage of Restaurants with Table Booking
#
# This section calculates the percentage of restaurants that offer table booking.

# %%
table_booking = df["Has Table booking"].value_counts(normalize=True) * 100

table_booking
# Out:
# Has Table booking
# No     87.864179
# Yes    12.135821
# Name: proportion, dtype: float64

# %% [markdown]
# ## Observation
#
# The percentage distribution shows the proportion of restaurants that offer table booking compared to those that do not.

# %%
import matplotlib.pyplot as plt

table_booking.plot(kind="bar")

plt.title("Percentage of Restaurants with Table Booking")
plt.xlabel("Table Booking")
plt.ylabel("Percentage")

plt.show()

# %% [markdown]
# ## Observation
#
# The bar chart clearly illustrates the difference between restaurants that offer table booking and those that do not, making it easier to compare their proportions.

# %% [markdown]
# # Average Rating Based on Table Booking
#
# This section compares the average aggregate rating of restaurants that offer table booking with those that do not.

# %%
df.groupby("Has Table booking")["Aggregate rating"].mean()
# Out:
# Has Table booking
# No     2.557956
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# ### Observation
#
# - Restaurants that offer table booking have a higher average rating (approximately **3.44**) compared to restaurants that do not offer table booking (approximately **2.56**).
# - This indicates that restaurants with table booking facilities generally receive better customer ratings.
# - The availability of table booking may be associated with improved customer experience and service quality.

# %%
df.groupby("Has Table booking")["Aggregate rating"].mean().plot(kind="bar")

plt.title("Average Rating by Table Booking")

plt.xlabel("Table Booking")

plt.ylabel("Average Rating")

plt.show()

# %% [markdown]
# ### Observation
#
# - The bar chart clearly shows that restaurants with **table booking ("Yes")** have noticeably higher average ratings than those without table booking ("No").
# - The difference in ratings suggests a positive relationship between table booking availability and customer satisfaction.
# - Overall, restaurants providing table booking tend to perform better in terms of customer ratings.

# %% [markdown]
# # Online Delivery Across Price Ranges
#
# This section analyzes the availability of online delivery across different restaurant price ranges.

# %%
pd.crosstab(df["Price range"], df["Has Online delivery"])
# Out:
# Has Online delivery    No   Yes
# Price range
# 1                    3737   701
# 2                    1827  1286
# 3                     994   411
# 4                     533    53

# %% [markdown]
# ### Observation
#
# - Price Range 1 has the highest number of restaurants, with 3,737 not offering online delivery and 701 offering online delivery.
# - Price Range 2 has a relatively balanced distribution, with 1,827 restaurants without online delivery and 1,286 with online delivery.
# - Price Range 3 has fewer restaurants, and online delivery is less common compared to lower price ranges.
# - Price Range 4 has the smallest number of restaurants, with only 53 restaurants providing online delivery.
# - Overall, restaurants without online delivery outnumber those offering online delivery across all price ranges.

# %%
pd.crosstab(df["Price range"], df["Has Online delivery"]).plot(kind="bar")

plt.title("Online Delivery Across Price Ranges")

plt.xlabel("Price Range")

plt.ylabel("Number of Restaurants")

plt.show()

# %% [markdown]
# ### Observation
#
# - The bar chart clearly shows that restaurants without online delivery are more common in every price range.
# - Online delivery is most frequently available among Price Range 2 restaurants.
# - Price Range 1 contains the largest number of restaurants overall, but only a small proportion offer online delivery.
# - Very few premium restaurants (Price Range 4) provide online delivery services.
# - This suggests that online delivery is more popular among low- and mid-priced restaurants than among expensive restaurants.

# %% [markdown]
# ## Final Summary
#
# In this task, the availability of table booking and online delivery services was analyzed along with their relationship to restaurant ratings and price ranges.
#
# The analysis showed that only a small percentage of restaurants offer table booking, while the majority do not. However, restaurants that provide table booking have a noticeably higher average aggregate rating than those without this service.
#
# The availability of online delivery was also examined across different price ranges. Most restaurants, regardless of their price range, do not offer online delivery. Online delivery is more common among low- and mid-priced restaurants, whereas high-end restaurants are less likely to provide this service.
#
# Overall, the results indicate that value-added services such as table booking are associated with higher customer ratings, while online delivery is primarily offered by restaurants in the lower and middle price categories.

# %% [markdown]
# # Level 2 - Task 2: Price Range Analysis
#
# ## Objective
#
# The objective of this task is to analyze the distribution of restaurant price ranges, calculate the average rating for each price range, and identify the rating color associated with the highest average rating.

# %% [markdown]
# ## Most Common Price Range
#
# This section identifies the most frequently occurring price range in the dataset.

# %%
# Count restaurants in each price range
df["Price range"].value_counts()
# Out:
# Price range
# 1    4438
# 2    3113
# 3    1405
# 4     586
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["Price range"].value_counts().sort_index().plot(kind="bar")

plt.title("Distribution of Restaurants by Price Range")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")

plt.show()

# %% [markdown]
# ### Observation
#
# - Price Range 1 contains the highest number of restaurants.
# - The number of restaurants decreases as the price range increases.
# - Price Range 4 has the fewest restaurants.
# - This indicates that low-cost restaurants are more common in the dataset than expensive restaurants.

# %% [markdown]
# ## Average Rating by Price Range
#
# This section calculates the average aggregate rating for restaurants in each price range.

# %%
df.groupby("Price range")["Aggregate rating"].mean()
# Out:
# Price range
# 1    1.997476
# 2    2.941054
# 3    3.682633
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %%
df.groupby("Price range")["Aggregate rating"].mean().plot(kind="bar")

plt.title("Average Rating by Price Range")
plt.xlabel("Price Range")
plt.ylabel("Average Rating")

plt.show()

# %% [markdown]
# Observation:
# The analysis shows that the average restaurant rating increases as the price range increases. Restaurants in Price Range 1 have the lowest average rating (approximately 2.00), while those in Price Range 4 have the highest average rating (approximately 3.82). This indicates a positive relationship between price range and customer ratings, suggesting that higher-priced restaurants generally receive better ratings, possibly due to better food quality, service, and overall dining experience.

# %% [markdown]
# ## Rating Color Associated with Highest Average Rating
#
# This section identifies which rating color corresponds to the highest average aggregate rating.

# %%
df.groupby("Rating color")["Aggregate rating"].mean().sort_values(ascending=False)
# Out:
# Rating color
# Dark Green    4.659667
# Green         4.167904
# Yellow        3.683063
# Orange        3.051339
# Red           2.297849
# White         0.000000
# Name: Aggregate rating, dtype: float64

# %%
df.groupby("Rating color")["Aggregate rating"].mean().sort_values().plot(kind="barh")

plt.title("Average Rating by Rating Color")
plt.xlabel("Average Rating")
plt.ylabel("Rating Color")

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Observation:
# The analysis indicates that restaurants with the Dark Green rating color have the highest average rating (approximately 4.66), followed by Green (4.17), Yellow (3.68), Orange (3.05), and Red (2.30). The White rating color has an average rating of 0.00, representing unrated restaurants. This confirms that the rating colors accurately reflect restaurant performance, with Dark Green representing the highest-rated restaurants and Red/White representing the lowest or unrated restaurants.

# %% [markdown]
# ## Final Summary
#
# In this task, the distribution of restaurant price ranges and their relationship with customer ratings were analyzed. The analysis showed that Price Range 1 is the most common category, indicating that the dataset contains a larger number of budget-friendly restaurants.
#
# The average aggregate rating was calculated for each price range, revealing that restaurant ratings generally vary across different pricing categories. This suggests that the cost of dining alone does not determine customer satisfaction, as restaurants from multiple price ranges receive good ratings.
#
# Finally, the average rating was analyzed based on the rating color. The rating color associated with the highest average rating represents restaurants with the best customer satisfaction, confirming that the rating color effectively reflects the restaurant's overall performance.
#
# Overall, the analysis provides valuable insights into the relationship between restaurant pricing, customer ratings, and rating categories, helping to better understand customer preferences and restaurant quality across different price segments.

# %% [markdown]
# # Level 2 - Task 3: Feature Engineering
#
# ## Objective
#
# The objective of this task is to create new features from existing columns and convert categorical variables into numerical values to make the dataset more suitable for data analysis and machine learning.

# %% [markdown]
# ## Restaurant Name Length
#
# This section creates a new feature representing the number of characters in each restaurant's name.

# %%
df["Restaurant Name Length"] = df["Restaurant Name"].str.len()

df[["Restaurant Name", "Restaurant Name Length"]].head()
